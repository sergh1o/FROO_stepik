# %%
import pandas as pd

# %%
orders = pd.read_csv('orders.csv', delimiter=';')
orders
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
products = pd.read_csv('Products.csv',  delimiter=';', index_col='Product_ID')
products.shape
# Out:
#                                              Name  Price CURRENCY
# Product_ID
# 47                           Шатны Полосатый рейс   2999      RUR
# 51                       Платье Аленький цветочек   4999      RUR
# 53                         Штаны Цветочная Поляна   4999      RUR
# 71                            Платье Ночная Жизнь   7999      RUR
# 74                       Платье Ночная Жизнь XXXL   8999      RUR
# 86                             Носки Простые, муж     45      RUR
# 91                             Носки Честные, муж     50      RUR
# 103                         Носки Подарочные, муж    199      RUR
# 104                         Носки Подарочные, жен    249      RUR
# 124                          Носки беговые Camino    999      RUR
# 137                     Гольфы детские Снегурочка     99      RUR
# 138                      Гольфы детские Питер Пен     99      RUR
# 139                              Сумка для носков    500      RUR
# ...

# %%
print(products.shape)
print(orders.shape)
# Out:
# (14, 3)
# (18, 9)

# %%
merged = orders.merge(products, how='left', left_on='ID товара', right_index=True).dropna(axis=0)
merged['Total']  = merged['Количество'] * merged['Price']
#merged[merged[merged['Оплачен'] == 'Да']]
merged
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# ...

# %%
filter1 = merged[merged['Оплачен'] == 'Да']

# %%
filter2 = filter1[filter1.Name.str.contains('Носки').values]
filter2.Total.sum()
# Out:
# 1389.0

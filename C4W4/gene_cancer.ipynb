# %%
import statsmodels
import scipy as sc
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import matplotlib.pyplot as plt
from statsmodels.stats.multitest import multipletests

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
genes = pd.read_csv('gene_high_throughput_sequencing.csv')

# %%
genes.Diagnosis.unique()
# Out:
# array(['normal', 'early neoplasia', 'cancer'], dtype=object)

# %%
genes.iloc[::10,:6]
# Out:
#                    Patient_id        Diagnosis  LOC643837  LOC100130417  \
# 0   STT5425_Breast_001_normal           normal   1.257614      2.408148
# 10  STT5502_Breast_010_normal           normal   3.558222      6.270213
# 20  STT5756_Breast_022_normal           normal   2.234576      2.936809
# 30      STT5440_Breast_003_EN  early neoplasia   3.386331     12.379176
# 40      STT5612_Breast_017_EN  early neoplasia   4.567425      6.078425
# 50    STT5450_Breast_006_DCIS           cancer   1.609022     10.632542
# 60     STT5581_Breast_016_IDC           cancer   0.903290      1.729668
# 70     STT5763_Breast_022_IDC           cancer   3.733734      8.860505
#
#        SAMD11      NOC2L
# 0   13.368622   9.494779
# 10  18.380624  11.162901
# 20  13.791320  22.254160
# 30  28.350470  14.547256
# 40  14.829839  14.625044
# 50  28.344988  18.462903
# 60  15.775280  18.386628
# 70  32.538666  21.585069

# %%
#Расчет экспрессии

def  fold_change(C, T):
    if T > C:
        return T / C
    return -C / T

# %%
genes_expres = pd.DataFrame(columns=['gene', 'normal_to_early_tt', 'early_to_cancer_tt'])

# %%
for i, gene in enumerate(genes.drop(['Patient_id', 'Diagnosis'], axis=1).columns.values.tolist()):
    genes_expres.loc[i, 'gene'] = gene
    genes_expres.loc[i, 'normal_to_early_tt'] = sc.stats.ttest_ind(genes.loc[genes.Diagnosis == 'normal', gene],
                                                                   genes.loc[genes.Diagnosis == 'early neoplasia', gene],
                                                                   equal_var=False)[1]
    genes_expres.loc[i, 'early_to_cancer_tt'] = sc.stats.ttest_ind(genes.loc[genes.Diagnosis == 'early neoplasia', gene],\
                                                                   genes.loc[genes.Diagnosis == 'cancer', gene],
                                                                   equal_var=False)[1]

# %%
first_case = genes_expres['normal_to_early_tt'] < 0.05
second_case = genes_expres['early_to_cancer_tt'] < 0.05

print(genes_expres.loc[first_case].shape[0])
print(genes_expres.loc[second_case].shape[0])
# Out:
# 1575
# 3490

# %%
genes_expres.head()
# Out:
#            gene normal_to_early_tt early_to_cancer_tt
# 0     LOC643837           0.690766           0.413735
# 1  LOC100130417        3.17853e-05           0.653429
# 2        SAMD11          0.0602727          0.0795556
# 3         NOC2L           0.826429           0.287581
# 4        KLHL17          0.0498762           0.463292

# %%
reject, p_corrected, a1, a2 = multipletests(genes_expres['early_to_cancer_tt'], 
                                            alpha = 0.025, 
                                            method = 'holm')
genes_expres['early_to_cancer_tt_holm'] = p_corrected
genes_expres['early_to_cancer_tt_holm_rej'] = reject

# %%
reject, p_corrected, a1, a2 = multipletests(genes_expres['normal_to_early_tt'], 
                                            alpha = 0.025, 
                                            method = 'holm')
genes_expres['normal_to_early_tt_holm'] = p_corrected
genes_expres['normal_to_early_tt_holm_rej'] = reject

# %%
print(genes_expres[genes_expres['normal_to_early_tt_holm_rej']].shape[0])
print(genes_expres[genes_expres['early_to_cancer_tt_holm_rej']].shape[0])
# Out:
# 2
# 79

# %%
genes_expres.head()
# Out:
#            gene normal_to_early_tt early_to_cancer_tt normal_to_early_tt_holm  \
# 0     LOC643837           0.690766           0.413735                       1
# 1  LOC100130417        3.17853e-05           0.653429                0.500174
# 2        SAMD11          0.0602727          0.0795556                       1
# 3         NOC2L           0.826429           0.287581                       1
# 4        KLHL17          0.0498762           0.463292                       1
#
#    normal_to_early_tt_holm_rej early_to_cancer_tt_holm  \
# 0                        False                       1
# 1                        False                       1
# 2                        False                       1
# 3                        False                       1
# 4                        False                       1
#
#    early_to_cancer_tt_holm_rej
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %%
for gene in genes_expres['gene']:
    t = genes.loc[genes.Diagnosis == 'early neoplasia', gene]
    c = genes.loc[genes.Diagnosis == 'normal', gene]
    genes_expres.loc[genes_expres['gene'] == gene, 'fold_change_normal_to_early'] = fold_change(np.mean(c), np.mean(t))
    
    t = genes.loc[genes.Diagnosis == 'cancer', gene]
    c = genes.loc[genes.Diagnosis == 'early neoplasia', gene]
    genes_expres.loc[genes_expres['gene'] == gene, 'fold_change_early_to_cancer'] = fold_change(np.mean(c), np.mean(t))

# %%
genes_expres[genes_expres['normal_to_early_tt_holm_rej']]
# Out:
#         gene normal_to_early_tt early_to_cancer_tt normal_to_early_tt_holm  \
# 7244   PCSK4        7.95543e-07          0.0939552               0.0125274
# 9820  EEF1A2        8.49874e-08           0.574408              0.00133838
#
#       normal_to_early_tt_holm_rej early_to_cancer_tt_holm  \
# 7244                         True                       1
# 9820                         True                       1
#
#       early_to_cancer_tt_holm_rej  fold_change_normal_to_early
# 7244                        False                     1.509785
# 9820                        False                     1.974868

# %%
'''
for gene in genes_expres.loc[genes_expres['early_to_cancer_tt_holm_rej'], 'gene']:
    t = genes.loc[genes.Diagnosis == 'cancer', gene]
    c = genes.loc[genes.Diagnosis == 'early neoplasia', gene]
    genes_expres.loc[genes_expres['gene'] == gene, 'fold_change_early_to_cancer'] = fold_change(np.mean(c), np.mean(t))
    
'''

# %%
genes_expres[genes_expres['fold_change_early_to_cancer'] > 1.5]
# Out:
#            gene normal_to_early_tt early_to_cancer_tt normal_to_early_tt_holm  \
# 8         ISG15           0.240148         0.00074024                       1
# 47        GABRD         0.00301703        2.27604e-07                       1
# 125    C1orf127           0.909869          0.0145512                       1
# 182       MFAP2           0.884923        0.000888547                       1
# 186       PADI3          0.0643574           0.344465                       1
# 190       ACTL8           0.347963           0.102324                       1
# 193        PAX7           0.281326          0.0413797                       1
# 212     PLA2G2D           0.538042          0.0507605                       1
# 249                          False                       1
# 293                          False                       1
# 294                          False                0.651248
# 321                          False                       1
# 357                          False                       1
# 366                          False                       1
# 379                          False                       1
# 419                          False                       1
# 445                          False                       1
# 489                          False                       1
# 512                          False                       1
# 520                          False                       1
# 532                          False                       1
# 580                          False                       1
# 607                          False                       1
# 623                          False                       1
# 714                          False                       1
# 807                          False                       1
# 898                          False                       1
# ...                            ...                     ...
# 14500                        False                       1
# 14505                        False                       1
# 14522                        False                       1
# 14546                        False                       1
# 14644                        False                       1
# 14651                        False                       1
# 14671                        False                       1
# 14698                        False               0.0432517
# 14738                        False                       1
# 14831                        False                       1
# 14995                        False                       1
# 15022                        False                       1
# 15128                        False                       1
# 15129                        False                       1
# 15136                        False                       1
# 15145                        False                       1
# 15189                        False                       1
# 15210                        False                       1
# 15267                        False                       1
# 15383                        False                       1
# 15446                        False                       1
# 15452                        False                       1
# 15458                        False                       1
# 15462                        False                       1
# 15535                        False                       1
# 15536                        False                       1
# 15621                        False                       1
# 15627                        False                       1
# 15692                        False                       1
# 15700                        False                       1
#
#        early_to_cancer_tt_holm_rej  fold_change_normal_to_early  \
# 8                            False                     1.066094
# 47                            True                     1.311855
# 125                          False                     1.013395
# 182                          False                     1.018841
# 186                          False                     1.568106
# 190                          False                     1.168570
# 193                          False                     1.223940
# 212                          False                    -1.118322
# 234                          False                     1.871956
# 236                          False                    -1.172679
# 247                          False                    -1.006990
# 249                          False                     1.103834
# 293                          False                    -1.045547
# 294                          False                     1.188500
# 321                          False                     1.070770
# 357                          False                     1.476529
# 366                          False                     1.240543
# 379                          False                    -1.394747
# 419                          False                    -1.081516
# 445                          False                    -1.065380
# 489                          False                     1.700464
# 512                          False                    -1.164299
# 520                          False                     1.322908
# 532                          False                     1.130293
# 580                          False                     1.296560
# 607                          False                    -1.112976
# 623                          False                     1.188254
# 714                          False                    -1.024830
# 807                          False                     1.488117
# 898                          False                    -1.256142
# ...                            ...                          ...
# 14500                        False                     1.406594
# 14505                        False                    -1.111430
# 14522                        False                    -1.201851
# 14546                        False                     1.020470
# 14644                        False                     1.218232
# 14651                        False                     1.139458
# 14671                        False                    -1.390517
# 14698                        False                    -1.212126
# 14738                        False                    -1.014951
# 14831                        False                     1.268405
# 14995                        False                    -1.188701
# 15022                        False                     1.033865
# 15128                        False                    -1.025790
# 15129                        False                     1.165194
# 15136                        False                    -1.009678
# 15145                        False                     1.032049
# 15189                        False                    -1.138350
# 15210                        False                    -1.160379
# 15267                        False                     1.055619
# 15383                        False                     1.055470
# 15446                        False                    -1.039135
# 15452                        False                    -1.209825
# 15458                        False                    -1.264162
# 15462                        False                    -1.288328
# 15535                        False                     1.105168
# 15536                        False                    -1.220185
# 15621                        False                    -1.094013
# 15627                        False                    -1.395117
# 15692                        False                     1.216664
# 15700                        False                    -1.289774
#
# 14522                      False              0.868672
# 14546                      False              0.989824
# 14644                      False              0.854363
# 14651                      False              0.750453
# 14671                      False              0.745885
# 14698                       True               0.80054
# 14738                      False              0.992868
# 14831                       True              0.353137
# 14995                      False               0.84144
# 15022                       True              0.976381
# 15128                      False              0.971446
# 15129                       True              0.812552
# 15136                       True              0.993343
# 15145                      False              0.980777
# 15189                       True              0.816127
# 15210                       True              0.676321
# 15267                      False              0.979396
# 15383                       True              0.955434
# 15446                       True              0.977293
# 15452                      False              0.448695
# 15458                       True              0.502816
# 15462                       True              0.439867
# 15535                      False               0.96312
# 15536                      False              0.732874
# 15621                       True              0.867712
# 15627                       True              0.336396
# 15692                       True              0.739585
# 15700                       True              0.447725
#
#        normal_to_early_tt_bh_rej
# 8                          False
# 47                         False
# 125                        False
# 182                        False
# 186                        False
# 190                        False
# 193                        False
# 212                        False
# 234                        False
# 236                        False
# 247                        False
# 249                        False
# 293                        False
# 294                        False
# 321                        False
# 357                        False
# 366                        False
# 379                        False
# 419                        False
# 445                        False
# 489                        False
# 512                        False
# 520                        False
# 532                        False
# 580                        False
# 607                        False
# 623                        False
# 714                        False
# 807                        False
# 898                        False
# ...                          ...
# 14500                      False
# 14505                      False
# 14522                      False
# 14546                      False
# 14644                      False
# 14651                      False
# 14671                      False
# 14698                      False
# 14738                      False
# 14831                      False
# 14995                      False
# 15022                      False
# 15128                      False
# 15129                      False
# 15136                      False
# 15145                      False
# 15189                      False
# 15210                      False
# 15267                      False
# 15383                      False
# 15446                      False
# 15452                      False
# 15458                      False
# 15462                      False
# 15535                      False
# 15536                      False
# 15621                      False
# 15627                      False
# 15692                      False
# 15700                      False
#
# [451 rows x 13 columns]

# %%
reject, p_corrected, a1, a2 = multipletests(genes_expres['early_to_cancer_tt'], 
                                            alpha = 0.025, 
                                            method = 'fdr_bh')
genes_expres['early_to_cancer_tt_bh'] = p_corrected
genes_expres['early_to_cancer_tt_bh_rej'] = reject

reject, p_corrected, a1, a2 = multipletests(genes_expres['normal_to_early_tt'], 
                                            alpha = 0.025, 
                                            method = 'fdr_bh')
genes_expres['normal_to_early_tt_bh'] = p_corrected
genes_expres['normal_to_early_tt_bh_rej'] = reject

# %%
print(genes_expres[genes_expres['normal_to_early_tt_bh_rej']].shape[0])
print(genes_expres[genes_expres['early_to_cancer_tt_bh_rej']].shape[0])
# Out:
# 4
# 832

# %%
first = genes_expres['fold_change_normal_to_early'] > 1.5
second = genes_expres['fold_change_normal_to_early'] < -1.5
third = genes_expres['normal_to_early_tt_bh_rej']

genes_expres[third & (first | second)].shape[0]
# Out:
# 4

# %%
first = genes_expres['fold_change_early_to_cancer'] > 1.5
second = genes_expres['fold_change_early_to_cancer'] < -1.5
third = genes_expres['early_to_cancer_tt_bh_rej']

genes_expres[third & (first | second)].shape[0]
# Out:
# 524
